# %%
a=var('a')
r=var('r')

# %%
z(a,r)=sin(a*r)+a^2*r^2

# %%
z.diff(a,a)
# Out:
# (a, r) |--> -r^2*sin(a*r) + 2*r^2

# %%
z.diff(r,r)
# Out:
# (a, r) |--> -a^2*sin(a*r) + 2*a^2

# %%
z.diff(a,r,a)
# Out:
# (a, r) |--> -a*r^2*cos(a*r) - 2*r*sin(a*r) + 4*r

# %%
var('t,x')
var('n',domain=ZZ)
from sage.plot.plot3d.plot3d import axes

# %%
u = lambda m : (40/pi^2)*(1-cos(m*pi))*exp((-m^2*pi^2*25*t)/50^2)*sin((m*pi*x)/50)

# %%
S=var('S',domain=ZZ)
def seriestoS(x,t,S):
    return sum([u(m) for m in range(1,S+1)])

# %%
pl = plot3d(seriestoS(x,t,40),(x,0,50),(t,0,20),color='orange',opacity=0.3)
show(pl,figsize=20,viewer='jmol')
# Out:
# Graphics3d Object
